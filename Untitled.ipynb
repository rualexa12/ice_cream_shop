# %% [markdown]
# proyecto #2 prediciones de ingresos; eres dueño de un negocio de helados y quieres crear un model para predecir los ingresos diarios en dolares badados en la temperatura (degC);
#
# decidiste contruir una simple red neural artificial para resolver este problema; conjuto de datos: entrada (x): temperatura del aire exterior; salida(y): ingresos diarios totales generados en dolaresm
